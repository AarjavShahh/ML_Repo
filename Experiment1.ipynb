# %% [markdown]
# 1. XOR Problem (Neural Network)

# %%
import numpy as np

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

np.random.seed(42)
W1 = np.random.randn(2,2)
b1 = np.zeros((1,2))
W2 = np.random.randn(2,1)
b2 = np.zeros((1,1))

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_deriv(x):
    return x*(1-x)


lr = 0.1
for epoch in range(1000):
    z1 = np.dot(X, W1) + b1
    a1 = sigmoid(z1)
    z2 = np.dot(a1, W2) + b2
    a2 = sigmoid(z2)


    loss = np.mean((y - a2)**2)


    d_a2 = (a2 - y)
    d_z2 = d_a2 * sigmoid_deriv(a2)

    d_W2 = np.dot(a1.T, d_z2)
    d_b2 = np.sum(d_z2, axis=0, keepdims=True)

    d_a1 = np.dot(d_z2, W2.T)
    d_z1 = d_a1 * sigmoid_deriv(a1)

    d_W1 = np.dot(X.T, d_z1)
    d_b1 = np.sum(d_z1, axis=0, keepdims=True)


    W1 -= lr * d_W1
    b1 -= lr * d_b1
    W2 -= lr * d_W2
    b2 -= lr * d_b2

print("Predictions:")
print(a2.round())
# Out:
# Predictions:
# [[1.]
#  [0.]
#  [1.]
#  [0.]]

# %% [markdown]
# 2. Linear Regression (Neural Network)

# %%
import numpy as np

X = np.linspace(0,10,50).reshape(-1,1)
y = 2*X + 3

W = np.random.randn(1,1)
b = np.zeros((1,1))

lr = 0.01

for epoch in range(1000):
    y_pred = np.dot(X, W) + b


    loss = np.mean((y - y_pred)**2)


    dW = -2*np.mean(X*(y - y_pred))
    db = -2*np.mean(y - y_pred)


    W -= lr*dW
    b -= lr*db

print("Weight:", W)
print("Bias:", b)
# Out:
# Weight: [[2.00274823]]
# Bias: [[2.98163002]]

# %% [markdown]
# 3. Binary Classification (Pass/Fail)

# %%
import numpy as np

X = np.array([[30],[40],[50],[60],[70],[80]])
y = np.array([[0],[0],[0],[1],[1],[1]])


X = X/100


W = np.random.randn(1,1)
b = np.zeros((1,1))

def sigmoid(x):
    return 1/(1+np.exp(-x))

lr = 0.1

for epoch in range(2000):
    z = np.dot(X,W)+b
    y_pred = sigmoid(z)


    loss = -np.mean(y*np.log(y_pred)+(1-y)*np.log(1-y_pred))


    dW = np.dot(X.T, (y_pred - y))/len(X)
    db = np.mean(y_pred - y)


    W -= lr*dW
    b -= lr*db

print("Predictions:", (y_pred > 0.5).astype(int))
# Out:
# Predictions: [[0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]]

# %% [markdown]
# 4. Multi-Feature Classification

# %%
import numpy as np

X = np.array([[150,50],[160,60],[170,70],[180,80]])
y = np.array([[0],[0],[1],[1]])


X = X / np.max(X, axis=0)


W = np.random.randn(2,1)
b = np.zeros((1,1))

def sigmoid(x):
    return 1/(1+np.exp(-x))

lr = 0.1

for epoch in range(2000):
    z = np.dot(X,W)+b
    y_pred = sigmoid(z)

    loss = -np.mean(y*np.log(y_pred)+(1-y)*np.log(1-y_pred))

    dW = np.dot(X.T,(y_pred - y))/len(X)
    db = np.mean(y_pred - y)

    W -= lr*dW
    b -= lr*db

print("Predictions:", (y_pred>0.5).astype(int))
# Out:
# Predictions: [[0]
#  [0]
#  [1]
#  [1]]

# %% [markdown]
# 5. Digit Classification (5×5 Images)

# %%
import numpy as np


X = np.random.randint(0,2,(10,25))
y = np.eye(10)[:10]


W1 = np.random.randn(25,16)
b1 = np.zeros((1,16))
W2 = np.random.randn(16,10)
b2 = np.zeros((1,10))

def relu(x):
    return np.maximum(0,x)

def softmax(x):
    exp = np.exp(x - np.max(x,axis=1,keepdims=True))
    return exp/np.sum(exp,axis=1,keepdims=True)

lr = 0.01

for epoch in range(1000):
    a1 = relu(np.dot(X,W1)+b1)
    a2 = softmax(np.dot(a1,W2)+b2)


    loss = -np.mean(y*np.log(a2))


    dZ2 = a2 - y
    dW2 = np.dot(a1.T,dZ2)
    db2 = np.sum(dZ2,axis=0,keepdims=True)

    dA1 = np.dot(dZ2,W2.T)
    dZ1 = dA1 * (a1 > 0)

    dW1 = np.dot(X.T,dZ1)
    db1 = np.sum(dZ1,axis=0,keepdims=True)


    W1 -= lr*dW1
    b1 -= lr*db1
    W2 -= lr*dW2
    b2 -= lr*db2

print("Output shape:", a2.shape)
# Out:
# Output shape: (10, 10)
